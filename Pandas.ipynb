# %%
import pandas as pd
df = pd.read_excel("Attribute DataSet.xlsx")

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
# 4   876339541     cute      Low     4.5    M  Summer   o-neck    butterfly
#
#   waiseline       Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire            NaN    chiffon     ruffles       animal               1
# 1   natural     microfiber        NaN     ruffles       animal               0
# 2   natural       polyster        NaN         NaN        print               0
# 3   natural           silk    chiffon  embroidary        print               1
# 4   natural  chiffonfabric    chiffon         bow          dot               0

# %%
df.head(10)
# Out:
#      Dress_ID     Style    Price  Rating  Size  Season NeckLine SleeveLength  \
# 0  1006032852      Sexy      Low     4.6     M  Summer   o-neck    sleevless
# 1  1212192089    Casual      Low     0.0     L  Summer   o-neck        Petal
# 2  1190380701   vintage     High     0.0     L  Automn   o-neck         full
# 3   966005983     Brief  Average     4.6     L  Spring   o-neck         full
# 4   876339541      cute      Low     4.5     M  Summer   o-neck    butterfly
# 5  1068332458  bohemian      Low     0.0     M  Summer   v-neck    sleevless
# 6  1220707172    Casual  Average     0.0    XL  Summer   o-neck         full
# 7  1219677488   Novelty  Average     0.0  free  Automn   o-neck        short
# 8  1113094204     Flare  Average     0.0  free  Spring   v-neck        short
# 9   985292672  bohemian      Low     0.0  free  Summer   v-neck    sleevless
#
#   waiseline       Material  FabricType  Decoration Pattern Type  \
# ...

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
df.tail(6)
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 494  990559192   Brief  Average     4.7     M  winter     o-neck   halfsleeve
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 494   natural   acrylic     chiffon        NaN      striped               0
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# ...

# %%
df = pd.read_csv("haberman.csv")

# %%
df
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# ..   ..  ..  ..  ...
# 300  75  62   1    1
# 301  76  67   0    1
# 302  77  65   3    1
# 303  78  65   1    2
# 304  83  58   2    2
#
# [305 rows x 4 columns]

# %%
pd.read_csv("haberman.csv", names=["Age","pateint year of operation","Number of positive","survival status"])
# Out:
#      Age  pateint year of operation  Number of positive  survival status
# 0     30                         64                   1                1
# 1     30                         62                   3                1
# 2     30                         65                   0                1
# 3     31                         59                   2                1
# 4     31                         65                   4                1
# ..   ...                        ...                 ...              ...
# 301   75                         62                   1                1
# 302   76                         67                   0                1
# 303   77                         65                   3                1
# 304   78                         65                   1                2
# 305   83                         58                   2                2
#
# [306 rows x 4 columns]

# %%
pd.read_csv("DressSales.csv")
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# ..          ...        ...        ...       ...       ...       ...       ...
# 495   713391965          0          0         0       560       554       544
# 496   722565148          0          0         0       875       866       861
# 497   532874347          0          0         0       734       728       726
# 498   655464934          0          0         0       254       259       261
# 499   919930954          0          0         0       538       545       558
#
# ...

# %%
pd.read_csv("Haberman.csv",header =None,names=["Age","patient's year operation","Number of positives","survival Status"])
# Out:
#      Age  patient's year operation  Number of positives  survival Status
# 0     30                        64                    1                1
# 1     30                        62                    3                1
# 2     30                        65                    0                1
# 3     31                        59                    2                1
# 4     31                        65                    4                1
# ..   ...                       ...                  ...              ...
# 301   75                        62                    1                1
# 302   76                        67                    0                1
# 303   77                        65                    3                1
# 304   78                        65                    1                2
# 305   83                        58                    2                2
#
# [306 rows x 4 columns]

# %%
df = pd.read_excel("Attribute DataSet.xlsx")

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.columns
# Out:
# Index(['Dress_ID', 'Style', 'Price', 'Rating', 'Size', 'Season', 'NeckLine',
#        'SleeveLength', 'waiseline', 'Material', 'FabricType', 'Decoration',
#        'Pattern Type', 'Recommendation'],
#       dtype='object')

# %%
df.to_json('test123.json')

# %%
df.to_csv("filename.csv")

# %%
pwd
# Out:
# 'C:\\Users\\chera'

# %%
df
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df.to_csv("test1234.csv", index=False)

# %%
df1 = pd.read_csv("test1234.csv")

# %%
df1
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 495   713391965   Casual      Low     4.7     M  Spring     o-neck
# 496   722565148     Sexy      Low     4.3  free  Summer     o-neck
# 497   532874347   Casual  Average     4.7     M  Summer     v-neck
# 498   655464934   Casual  Average     4.6     L  winter  boat-neck
# 499   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength waiseline       Material  FabricType  Decoration  \
# 0      sleevless    empire            NaN     chiffon     ruffles
# ...

# %%
df1.head(4)
# Out:
#      Dress_ID    Style    Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852     Sexy      Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089   Casual      Low     0.0    L  Summer   o-neck        Petal
# 2  1190380701  vintage     High     0.0    L  Automn   o-neck         full
# 3   966005983    Brief  Average     4.6    L  Spring   o-neck         full
#
#   waiseline    Material FabricType  Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon     ruffles       animal               1
# 1   natural  microfiber        NaN     ruffles       animal               0
# 2   natural    polyster        NaN         NaN        print               0
# 3   natural        silk    chiffon  embroidary        print               1

# %%
df1.shape
# Out:
# (500, 14)

# %%
df = pd.read_csv("sales_data_final.csv")

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  object
#  2   ship_date       51290 non-null  object
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  object
#  15  quantity        51290 non-null  int64
#  16  discount        51290 non-null  float64
# ...

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df["customer_name"]
# Out:
# 0         Toby Braunhardt
# 1             Joseph Holt
# 2           Annie Thurman
# 3            Eugene Moren
# 4             Joseph Holt
#                ...
# 51285          Erica Bern
# 51286           Liz Preis
# 51287    Charlotte Melton
# 51288       Tamara Dahlen
# 51289       Jill Matthias
# Name: customer_name, Length: 51290, dtype: object

# %%
df['order_id']
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
#               ...
# 51285     CA-2014-115427
# 51286       MO-2014-2560
# 51287     MX-2014-110527
# 51288     MX-2014-114783
# 51289     CA-2014-156720
# Name: order_id, Length: 51290, dtype: object

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df[['order_id','order_date','customer_name']]
# Out:
#               order_id  order_date     customer_name
# 0         AG-2011-2040    1/1/2011   Toby Braunhardt
# 1        IN-2011-47883    1/1/2011       Joseph Holt
# 2         HU-2011-1220    1/1/2011     Annie Thurman
# 3      IT-2011-3647632    1/1/2011      Eugene Moren
# 4        IN-2011-47883    1/1/2011       Joseph Holt
# ...                ...         ...               ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern
# 51286     MO-2014-2560  12/31/2014         Liz Preis
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen
# 51289   CA-2014-156720  12/31/2014     Jill Matthias
#
# [51290 rows x 3 columns]

# %%
df[df.dtypes[df.dtypes=='object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#        discount    profit  shipping_cost
# 0           0.0  106.1400          35.46
# 1           0.1   36.0360           9.72
# 2           0.0   29.6400           8.17
# 3           0.5  -26.0550           4.82
# 4           0.1   37.7700           4.70
# ...         ...       ...            ...
# 51285       0.2    4.5188           0.89
# 51286       0.0    0.4200           0.49
# 51287       0.0   12.3600           0.35
# 51288       0.0    0.5600           0.20
# 51289       0.2   -0.6048           0.17
#
# [51290 rows x 3 columns]

# %%
df['order_id'][1:20:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# Name: order_id, dtype: object

# %%
df['new_column']= "Rohit"

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_id'].isnull().sum()
# Out:
# 0

# %%
df['quantity'].isnull().sum()
# Out:
# 0

# %%
df[df['profit']==min(df['profit'])]
# Out:
#              order_id  order_date  ship_date       ship_mode  customer_name  \
# 31884  CA-2013-108196  11/26/2013  12/3/2013  Standard Class  Cindy Stewart
#
#         segment state        country market region  ... sub_category  \
# 31884  Consumer  Ohio  United States     US   East  ...     Machines
#
#                                     product_name  sales quantity discount  \
# 31884  Cubify CubeX 3D Printer Double Head Print  4,500        5      0.7
#
#          profit  shipping_cost  order_priority  year new_column
# 31884 -6599.978         451.63             Low  2013      Rohit
#
# [1 rows x 22 columns]

# %%
df[df['profit'] == min(df['profit'])][['profit','customer_name', 'country', 'state']]
# Out:
#          profit  customer_name        country state
# 31884 -6599.978  Cindy Stewart  United States  Ohio

# %%
df[df['profit'] == max(df['profit'])]
# Out:
#              order_id order_date   ship_date       ship_mode customer_name  \
# 29530  CA-2013-118689  10/3/2013  10/10/2013  Standard Class  Tamara Chand
#
#          segment    state        country market   region  ... sub_category  \
# 29530  Corporate  Indiana  United States     US  Central  ...      Copiers
#
#                                 product_name   sales quantity discount  \
# 29530  Canon imageCLASS 2200 Advanced Copier  17,500        5      0.0
#
#          profit  shipping_cost  order_priority  year new_column
# 29530  8399.976         349.07          Medium  2013      Rohit
#
# [1 rows x 22 columns]

# %%
df[df['country'] == 'Sweden']
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# ...                ...         ...         ...             ...
# 50948  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50949  IT-2014-5217096  12/26/2014  12/31/2014  Standard Class
# 50972  IT-2014-4046179  12/27/2014  12/30/2014    Second Class
# 51086  IT-2014-2362249  12/29/2014    1/1/2015     First Class
# 51121  IT-2014-2362249  12/29/2014    1/1/2015     First Class
#
#          customer_name      segment            state country market region  \
# 3         Eugene Moren  Home Office        Stockholm  Sweden     EU  North
# ...

# %%
df[(df['shipping_cost'] > 100 ) & (df['profit'] < 10 )]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# ...

# %%
date = pd.to_datetime(df['order_date'])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_year'] = df['converted_order_date'].dt.year

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df['order_date_month'] = df['converted_order_date'].dt.month

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# ...

# %%
df[df['order_date_year']==2011]
# Out:
# Empty DataFrame
# Columns: [order_id, order_date, ship_date, ship_mode, customer_name, segment, state, country, market, region, product_id, category, sub_category, product_name, sales, quantity, discount, profit, shipping_cost, order_priority, year, new_column, converted_order_date, order_date_year, order_date_month]
# Index: []
#
# [0 rows x 25 columns]

# %%
df['order_date_month'].value_counts()
# Out:
# order_date_month
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: count, dtype: int64

# %%
df['cost_to_compny'] = df['discount'] + df["shipping_cost"]

# %%
df.drop('cost_to_company', axis =1 ,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.drop('cost_to_company', axis =1 ,inplace=True)
#
# NameError: name 'df' is not defined

# %%
df.loc[[2,3]]
# Out:
#           order_id order_date ship_date     ship_mode  customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011  Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011  Second Class   Eugene Moren
#
#        segment      state  country market region  ... discount  profit  \
# 2     Consumer   Budapest  Hungary   EMEA   EMEA  ...      0.0  29.640
# 3  Home Office  Stockholm   Sweden     EU  North  ...      0.5 -26.055
#
#   shipping_cost order_priority  year  new_column  converted_order_date  \
# 2          8.17           High  2011       Rohit            2011-01-01
# 3          4.82           High  2011       Rohit            2011-01-01
#
#    order_date_year  order_date_month cost_to_compny
# 2                1                 1           8.17
# 3                1                 1           5.32
#
# [2 rows x 26 columns]

# %%
df.iloc[0:4,0:3]
# Out:
#           order_id order_date ship_date
# 0     AG-2011-2040   1/1/2011  1/6/2011
# 1    IN-2011-47883   1/1/2011  1/8/2011
# 2     HU-2011-1220   1/1/2011  1/5/2011
# 3  IT-2011-3647632   1/1/2011  1/5/2011
